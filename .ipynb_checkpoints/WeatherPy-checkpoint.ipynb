# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from IPython.display import clear_output, display, Math

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
city = []
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []
date = []

print('Beginning Data Retrieval')
print('-----------------------------')
nn = 1
for cit in cities:
    if nn % 10 == 1:
        clear_output()
    print(f'Processing Record {nn}: {cit}')
    nn += 1
    response = requests.get(query_url + cit).json()
    try:
        city.append(response['name']) # City name
        longitude.append(response['coord']['lon']) # Longitude
        latitude.append(response['coord']['lat']) # Latitude
        country.append(response['sys']['country']) # Country
        cloudiness.append(response['clouds']['all']) # Cloudiness?
        humidity.append(response['main']['humidity']) # Humidity
        max_temp.append(response['main']['temp_max']) # Max Temp
        wind_speed.append(response['wind']['speed']) # Wind Speed
        date.append(time.localtime(response['dt'])[0:3]) # Date
    except (KeyError, AttributeError):
        print(f'City {city} not found. Skipping...')
print('-----------------------------')
print('Data Retrieval Complete')      
print('-----------------------------')
# Out:
# Processing Record 621: oranjestad
# Processing Record 622: kamloops
# Processing Record 623: remontnoye
# Processing Record 624: rudbar
# Processing Record 625: west bay
# Processing Record 626: sorvag
# City ['Elko', 'Ushuaia', 'Saint Paul Harbor', 'Punta Arenas', 'Albany', 'Port Hardy', 'Hermanus', 'Mataura', 'Provideniya', 'Leshukonskoye', 'Khatanga', 'Lengshuitan', 'Upernavik', 'Qaanaaq', 'Nakamura', 'Atuona', 'Fairbanks', 'Dagana', 'Bandarbeyla', 'Tambo', 'Timmins', 'Hastings', 'Jiblah', 'Rikitea', 'Stornoway', 'Conde', 'Ribeira Grande', 'Lavrentiya', 'Barrow', 'Hasaki', 'Svetlopolyansk', 'Chokurdakh', 'Toora-Khem', 'Vaini', 'Hanmer Springs', 'Kahului', 'Rodrigues Alves', 'Purnia', 'Hilo', 'Hobart', 'Busselton', 'Cape Town', 'Nanortalik', 'Arraial do Cabo', 'Cabo San Lucas', 'Saskylakh', 'Touros', 'Paamiut', 'Jamestown', 'Kirakira', 'Biabou', 'Apac', 'Pochutla', 'Vanimo', 'Pisco', 'Bluff', 'Longyearbyen', 'Butaritari', 'Geraldton', 'George Town', 'Mīrābād', 'Alyangula', 'Iqaluit', 'Bengkulu', 'Tilichiki', 'Ponta do Sol', 'Mahébourg', 'Cherskiy', 'Bambous Virieux', 'Siteki', 'Tiksi', 'Vathy', 'Hithadhoo', 'Mayo', 'Hong Kong', 'Ilhabela', 'Dikson', 'Soyo', 'Juba', 'Hamilton', 'Peniche', 'Salalah', 'Adrar', 'Remanso', 'Nivala', 'Ostrovnoy', 'Naryan-Mar', 'Waingapu', 'Saint-Philippe', 'Khor', 'Odesa', 'Bredasdorp', 'Srednekolymsk', 'Husavik', 'Taltal', 'Lola', 'San Vicente de Cañete', 'Avarua', 'Antofagasta', 'Gonder', 'Vardø', 'George', 'Saint-Léonard', 'Shimoda', 'Sorong', 'Upala', 'Korla', 'Härnösand', 'Maravilha', 'Le Port', 'Puerto Ayora', 'Lüderitz', 'Bhadrak', 'Buenavista', 'São Filipe', 'Songjianghe', 'Homer', 'Yar-Sale', 'Alugan', 'Nizhniy Ufaley', 'São João da Barra', 'Palmer', 'Yuli', 'Kapaa', 'Caravelas', 'Pevek', 'Faanui', 'Najrān', 'Tasiilaq', 'Clyde River', 'Constitución', 'Camalú', 'Margate', 'Mossamedes', 'Takoradze', 'Goderich', 'Marzuq', 'Carnarvon', 'Bara', 'Norman Wells', 'New Norfolk', 'Zdvinsk', 'Bathsheba', 'Port Elizabeth', 'Rochester', 'Poum', 'Trelew', 'Kaitangata', 'Kitimat', 'Ishikari', 'Maragogi', 'Ilulissat', 'Przhevalskoye', 'Mpika', 'Lagoa', 'Hofn', 'Leningradskiy', 'Santa Flavia', 'Yagodnoye', 'Thompson', 'Knysna', 'Safford', 'Barwādih', 'Bilibino', 'Skoghall', 'Mananjary', 'Port Alfred', 'Torbay', 'Zheleznodorozhnyy', 'Mount Isa', 'Minas', 'Benghazi', 'San Quintín', 'Praia', 'Nioro', 'Skjern', 'Macas', 'Bokoro', 'Ugra', 'Nampula', 'São José da Coroa Grande', 'Lompoc', 'Tongzi', 'Saint George', 'Boa Vista', 'Te Anau', 'Kunya', 'Samarai', 'Uspenka', 'Nanhai', 'Portland', 'Debre Tabor', 'Batagay-Alyta', 'Shache', 'Yārāda', 'Bukene', 'Castro', 'Solnechnyy', 'Revda', 'Airai', 'Kindu', 'Souillac', 'Cayenne', 'Nakhabino', 'Mareeba', 'Vila Velha', 'Lar', 'Saint-Louis', 'Lovozero', 'Port Lincoln', 'Rio Grande', 'Klaksvík', 'Ferrol', 'Neiafu', 'Vanavara', 'Leiyang', 'Gari', 'Ballina', 'Los Llanos de Aridane', 'Sitka', 'Lindi', 'Makaha', 'Monte Alegre', 'Chake Chake', 'Vilyuysk', 'Fortuna', 'Krasnyy Yar', 'Beloha', 'San Patricio', 'Cap Malheureux', 'Salinópolis', 'Qasigiannguit', 'Sumbawanga', 'Haines Junction', 'Bisira', 'Terra Rica', 'Payakumbuh', 'Tuktoyaktuk', 'Acapulco de Juárez', 'Ostrov', 'Mount Gambier', 'Amapá', 'Jardim', 'Røros', 'Dunedin', 'Opuwo', 'Bunog', 'Wagar', 'San Fernando', 'Pāsighāt', 'Jumla', 'Diamantino', 'Isabela', 'Ancud', 'Ivanovice na Hané', "Severo-Kuril'sk", "Lebyazh'ye", 'Kristinehamn', 'Arinos', 'Waipawa', 'Atasū', 'Yellowknife', 'Quatre Cocos', 'Paragominas', 'Buritis', 'Krasnokamensk', 'Palana', 'Valday', 'Berlevåg', 'Chui', 'Mitú', 'Elwood', 'Cidreira', 'Yong’an', 'Akçaabat', 'Bhatgaon', 'Isangel', 'Nikolskoye', 'Placerville', 'Shenjiamen', "Ust'-Karsk", 'Port Hedland', 'Batemans Bay', 'Tuatapere', 'Mar del Plata', 'Egvekinot', 'Provincie Utrecht', 'Kumul', 'Sinnamary', 'Beringovskiy', 'Alofi', 'Puerto Berrío', 'Gurupá', 'Harper', 'Buraidah', 'Nantucket', 'Tambacounda', 'Raton', 'Arlit', 'São Félix do Xingu', 'Laguna', 'Jaqué', 'Tagusao', 'Khovd', 'Talnakh', "Severobaykal'sk", 'East London', 'Plettenberg Bay', 'Lata', 'Loukhi', 'Atar', 'Oistins', 'Kalamata', 'San Cristobal', '‘Ewa Beach', 'Taksimo', 'Halifax', 'Santiago', 'Padang', 'Dingle', 'Chifeng', 'Les Cayes', 'Agu ...
# Processing Record 627: kaabong
# Processing Record 628: mogok
# Processing Record 629: novyy urengoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# City          535
#
# Cloudiness    535
#
# Country       535
#
# Date          535
#
# Humidity      535
#
# Lat           535
#
# Lng           535
#
# Max Temp      535
#
# Wind Speed    535

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame(
    {
        'City': city,
        'Country': country,
        'Longitude': longitude,
        'Latitude': latitude,
        'Humidity': humidity,
        'Cloudiness': cloudiness,
        'Humidity': humidity,
        'Max_Temp': max_temp,
        'Wind_Speed': wind_speed,
        'Date': date
    }
)

df.Max_Temp = 9.0/5.0 * df.Max_Temp + 32
df.to_csv('weather.csv', index=False)
df.head()
# Out:
#                 City Country  Longitude  Latitude  Humidity  Cloudiness  \
# 0               Elko      US    -115.50     41.00        40          40
# 1            Ushuaia      AR     -68.30    -54.80        67          40
# 2  Saint Paul Harbor      US    -152.41     57.79        36           1
# 3       Punta Arenas      CL     -70.92    -53.15        67          97
# 4             Albany      US     -73.97     42.60        86          90
#
#    Max_Temp  Wind_Speed           Date
# 0    53.006        4.60  (2020, 3, 23)
# 1    60.800        7.20  (2020, 3, 23)
# 2    46.400       11.80  (2020, 3, 23)
# 3    60.800       11.80  (2020, 3, 23)
# 4    33.998        3.19  (2020, 3, 23)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(df.Latitude, df.Max_Temp, edgecolors='black', zorder=2)
datestring = f'{df.Date[0][1]}/{df.Date[0][2]}/{df.Date[0][0]}'
plt.title(f'City Latitude vs. Max Temperature ({datestring})')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(zorder=0)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df.Latitude, df.Humidity, edgecolors='black', zorder=2)
plt.title(f'City Latitude vs. Humidity ({datestring})')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(zorder=0)

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df.Latitude, df.Cloudiness, edgecolors='black', zorder=2)
plt.title(f'City Latitude vs. Cloudiness ({datestring})')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(zorder=0)

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df.Latitude, df.Wind_Speed, edgecolors='black', zorder=2)
plt.title(f'City Latitude vs. Wind Speed ({datestring})')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(zorder=0)

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def plotLinReg(x_values, y_values, xlabel = '', ylabel = '', title = '', eqnx = 0, eqny = 0):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.annotate(line_eq, (eqnx, eqny), fontsize=15, color="red")
    display(Math(f'R^2 = {round(rvalue, 3)}'))

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df = df[df.Latitude > 0]
south_df = df[df.Latitude < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plotLinReg(north_df.Latitude, north_df.Max_Temp, xlabel = 'Latitude', ylabel = 'Max Temp (F)',
          title = "Regression: Max Temp vs. Latitude\n in the Northern Hemisphere",
          eqnx = 0, eqny = -30)
# Out:
# $\displaystyle R^2 = -0.899$

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plotLinReg(south_df.Latitude, south_df.Max_Temp, xlabel = 'Latitude', ylabel = 'Max Temp (F)',
          title = "Regression: Max Temp vs. Latitude\n in the Southern Hemisphere",
          eqnx = -24, eqny = 38)
# Out:
# $\displaystyle R^2 = 0.537$

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plotLinReg(north_df.Latitude, north_df.Humidity, xlabel = 'Latitude', ylabel = 'Humidity (%)',
          title = "Regression: Max Temp vs. Humidity\n in the Northern Hemisphere",
          eqnx = 40, eqny = 5)
# Out:
# $\displaystyle R^2 = 0.256$

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plotLinReg(south_df.Latitude, south_df.Humidity, xlabel = 'Latitude', ylabel = 'Humidity (%)',
          title = "Regression: Max Temp vs. Humidity\n in the Southern Hemisphere",
          eqnx = -25, eqny = 5)
# Out:
# $\displaystyle R^2 = 0.203$

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plotLinReg(north_df.Latitude, north_df.Cloudiness, xlabel = 'Latitude', ylabel = 'Cloudiness (%)',
          title = "Regression: Max Temp vs. Cloudiness\n in the Northern Hemisphere",
          eqnx = 40, eqny = 5)
# Out:
# $\displaystyle R^2 = 0.225$

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plotLinReg(south_df.Latitude, south_df.Humidity, xlabel = 'Latitude', ylabel = 'Cloudiness (%)',
          title = "Regression: Max Temp vs. Cloudiness\n in the Southern Hemisphere",
          eqnx = 40, eqny = 5)
# Out:
# $\displaystyle R^2 = 0.203$

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plotLinReg(north_df.Latitude, north_df.Wind_Speed, xlabel = 'Latitude', ylabel = 'Wind Speed (mph)',
          title = "Regression: Wind Speed vs. Latitude\n in the Northern Hemisphere",
          eqnx = 0, eqny = 13.5)
# Out:
# $\displaystyle R^2 = 0.132$

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plotLinReg(south_df.Latitude, south_df.Wind_Speed, xlabel = 'Latitude', ylabel = 'Wind Speed (mph)',
          title = "Regression: Wind Speed vs. Latitude\n in the Southern Hemisphere",
          eqnx = -21, eqny = 12)
# Out:
# $\displaystyle R^2 = -0.264$
